# %%
from langchain.llms import HuggingFaceEndpoint
from langchain_community.llms import HuggingFaceHub

import os

# Correct parameter name
endpoint_url = "https://api-inference.huggingface.co/models/meta-llama/Meta-Llama-3-8B-Instruct"

llm = HuggingFaceEndpoint(
    endpoint_url=endpoint_url,  
    huggingfacehub_api_token=os.environ['HF_TOKEN'],
    max_new_tokens=500,
    temperature=0.7,
    top_k=50,
    top_p=0.95
)
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
from huggingface_hub import whoami
import os

print(whoami(os.environ["HF_TOKEN"]))
# Out:
# {'type': 'user', 'id': '65461630117ecae648ae0a86', 'name': 'Bhavesh04', 'fullname': 'Bhavesh Wagh', 'isPro': False, 'avatarUrl': '/avatars/70b72a396afd705cfc4949727fcf90a6.svg', 'orgs': [], 'auth': {'type': 'access_token', 'accessToken': {'displayName': 'search engine', 'role': 'fineGrained', 'createdAt': '2025-02-01T16:39:27.009Z', 'fineGrained': {'canReadGatedRepos': False, 'global': [], 'scoped': [{'entity': {'_id': '65461630117ecae648ae0a86', 'type': 'user', 'name': 'Bhavesh04'}, 'permissions': []}]}}}}

# %%
from duckduckgo_search import DDGS
from langchain.tools import BaseTool


class WebSearch(BaseTool):
    name: str = "Search Engine"
    description: str = "Use this search Engine to answer the user query based on Web search"
     
     
    def _run(self,query: str):
        results = DDGS().text(query,max_results=10)
        all_results = ""
        for  i in range(len(results)):
            search_results = results[i]['title'] + results[i]['body']
            all_results += search_results + "\n\n"
            
        return all_results
    
web_tool = WebSearch()

# %%
from langchain.agents import AgentType, initialize_agent

tools = [web_tool]

agent = initialize_agent(
    tools = tools,
    llm = llm,
    agent_type = AgentType.REACT_DOCSTORE,
    max_iterations = 5,
    verbose = True
    
    
    
)

# %%
agent.run("abcd")
# Out:
# > Entering new AgentExecutor chain...
# c:\Users\bhave\anaconda3\envs\serach\Lib\site-packages\huggingface_hub\utils\_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 agent.run("abcd")
#
# File c:\Users\bhave\anaconda3\envs\serach\Lib\site-packages\langchain_core\_api\deprecation.py:181, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     179     warned = True
# ...

# %%
from huggingface_hub import InferenceClient
import os

# Define your model endpoint
endpoint_url = "https://api-inference.huggingface.co/models/meta-llama/Meta-Llama-3-8B-Instruct"

# Initialize InferenceClient
client = InferenceClient(endpoint_url, token=os.environ['HF_TOKEN'])

# Define a function to run the model
def query_model(prompt):
    response = client.text_generation(prompt, max_new_tokens=500, temperature=0.7, top_k=50, top_p=0.95)
    return response

# Test the function
print(query_model("What is today's date?"))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\bhave\anaconda3\envs\serach\Lib\site-packages\huggingface_hub\utils\_http.py:406, in hf_raise_for_status(response, endpoint_name)
#     405 try:
# --> 406     response.raise_for_status()
#     407 except HTTPError as e:
#
# File c:\Users\bhave\anaconda3\envs\serach\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://api-inference.huggingface.co/models/meta-llama/Meta-Llama-3-8B-Instruct
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# Cell In[9], line 16
#      13     return response
#      15 # Test the function
# ...

# %%
HF_API_KEY = os.environ.get("HF_API_KEY")
HF_API_URL = "https://api-inference.huggingface.co/models/meta-llama/Meta-Llama-3-8B-Instruct"

# %%
from huggingface_hub import InferenceClient
from langchain.llms import HuggingFacePipeline
from langchain.agents import initialize_agent, AgentType
from langchain.tools import Tool
from transformers import pipeline
from datetime import datetime

"""# Function to get today's date
def get_today_date():
    return datetime.today().strftime('%Y-%m-%d')

# Define the tool
date_tool = Tool(
    name="Get Today's Date",
    func=get_today_date,
    description="Returns the current date."
)"""

# Hugging Face API Key (Ensure you have your token set as an environment variable)
HF_API_TOKEN = "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"

# Initialize the Inference Client for Llama-3-8B-Instruct
client = InferenceClient(
    model="deepseek-ai/DeepSeek-R1",
    token=HF_API_TOKEN
)

# Define LLM Pipeline
llm_pipeline = pipeline(
    "text-generation",
    model="deepseek-ai/DeepSeek-R1",
    token=HF_API_TOKEN
)

# Initialize Langchain LLM
llm = HuggingFacePipeline(pipeline=llm_pipeline)

from duckduckgo_search import DDGS
from langchain.tools import BaseTool


class WebSearch(BaseTool):
    name: str = "Search Engine"
    description: str = "Use this search Engine to answer the user query based on Web search"
     
     
    def _run(self,query: str):
        results = DDGS().text(query,max_results=10)
        all_results = " "
        for  i in range(len(results)):
            search_results = results[i]['title'] + results[i]['body']
            all_results += search_results + "\n\n"
            
        return all_results
    
web_tool = WebSearch()

# Initialize the agent
agent = initialize_agent(
    tools=[web_tool],
    llm=llm,
    agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION,
    verbose=True
)

# Run the agent
response = agent.run("What is today's date?")
print(response)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\bhave\anaconda3\envs\serach\Lib\site-packages\transformers\dynamic_module_utils.py:649, in resolve_trust_remote_code(trust_remote_code, model_name, has_local_code, has_remote_code)
#     648 try:
# --> 649     prev_sig_handler = signal.signal(signal.SIGALRM, _raise_timeout_error)
#     650     signal.alarm(TIME_OUT_REMOTE_CODE)
#
# AttributeError: module 'signal' has no attribute 'SIGALRM'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 29
#      23 client = InferenceClient(
#      24     model="deepseek-ai/DeepSeek-R1",
#      25     token=HF_API_TOKEN
#      26 )
#      28 # Define LLM Pipeline
# ---> 29 llm_pipeline = pipeline(
#      30     "text-generation",
# ...

# %%
from huggingface_hub import login
login(token = "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")
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
